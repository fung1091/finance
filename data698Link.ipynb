# %% [markdown]
# # data698 link
#
# ## slack
# - https://join.slack.com/t/data698/shared_invite/enQtNTUwMTcwNTgzMzQ2LTAxZmRjNzVmNzVlYWExZDdlMmI3NWMyZjcyYjc2YzAwOWY0NGE1YzRlMGI1ODA4NWJkZTNhYWM3OTcwOTIzNTA
# - N: TzeFung Lung
# - DN: Jim Lung
# - pw: Hxxd1xx4@

# %% [markdown]
# ##
# - Dashboard
# - Docker link
# - Flask
# - GSP
# - AWD
# - NLP
# - Chatboard
# - other ML e.g. decision tree, a/b test, SVM
#
# ##
#
# - https://medium.com/@pdquant/stocks-significance-testing-p-hacking-how-volatile-is-volatile-1a0da3064b8a
# - https://github.com/bballboy21/stock_surface
# - https://github.com/topics/stock-price-prediction?o=desc&s=stars
# - https://github.com/huseinzol05/Stock-Prediction-Models
# - https://github.com/huseinzol05
# - https://github.com/robertmartin8/MachineLearningStocks
# - https://github.com/topics/stock-prediction
# - https://towardsdatascience.com/python-for-finance-stock-portfolio-analyses-6da4c3e61054
# - https://ntguardian.wordpress.com/2016/09/19/introduction-stock-market-data-python-1/
#
#
# - https://www.analyticsvidhya.com/blog/2018/10/predicting-stock-price-machine-learningnd-deep-learning-techniques-python/
# - https://towardsdatascience.com/stock-prediction-in-python-b66555171a2
# - https://towardsdatascience.com/predicting-stock-prices-with-python-ec1d0c9bece1
# - https://www.datacamp.com/community/tutorials/lstm-python-stock-market
# - https://github.com/topics/stock-price-prediction?l=python
#
# - https://github.com/WayneDW/Sentiment-Analysis-in-Event-Driven-Stock-Price-Movement-Prediction
#
# - https://github.com/philipxjm/Deep-Convolution-Stock-Technical-Analysis
# - https://github.com/Prakash2403/Chase
#
# - https://github.com/antonkorbalev/stockdataprocessing
# - https://github.com/mohabmes/StockNN
# - https://github.com/OpenXAIProject/Automatic-Stock-Trading
# - https://github.com/SakaiTakao/StockPrediction
# - https://github.com/gdroguski/GaussianProcesses#summary
# - https://github.com/ahmedhamdi96/ML4T
# - https://medium.com/ml-everything/predicting-the-stock-market-p-hacking-and-why-you-should-be-bullish-90fddc583838
# - https://github.com/ahmedhamdi96/ML4T
# - https://github.com/kaiserxc/DATA698_Capstone_Project/blob/master/Proposals/MidTerm.pdf
# - https://towardsdatascience.com/efficient-frontier-portfolio-optimisation-in-python-e7844051e7f
# - https://medium.com/ml-everything/predicting-the-stock-market-p-hacking-and-why-you-should-be-bullish-90fddc583838
# - https://towardsdatascience.com/stock-prediction-in-python-b66555171a2
#
# ### Main
# - https://pythonprogramming.net/quantopian-trading-strategies-introduction-python-programming-for-finance/
# - https://www.analyticsvidhya.com/blog/2016/02/time-series-forecasting-codes-python/
# - https://ntguardian.wordpress.com/2018/07/17/stock-data-analysis-python-v2/
# - https://github.com/rasbt/python_reference
#
#
# ### git html output
# - https://stackoverflow.com/questions/6551446/can-i-run-html-files-directly-from-github-instead-of-just-viewing-their-source
# - https://pages.github.com/
#
# ### HK stock symbol
# - http://eoddata.com/stocklist/HKEX.htm
# - https://www.hkex.com.hk/eng/dwrc/download/dnfile.asp
#
# ### visualization
# - https://ntguardian.wordpress.com/2018/07/17/stock-data-analysis-python-v2/
# - https://www.datacamp.com/community/tutorials/finance-python-trading
# - https://towardsdatascience.com/data-visualization-with-bokeh-in-python-part-iii-a-complete-dashboard-dc6a86aa6e23
# - https://cloud.google.com/solutions/bokeh-and-bigquery-dashboards
# - https://dash.plot.ly/gallery
# - https://blog.sicara.com/bokeh-dash-best-dashboard-framework-python-shiny-alternative-c5b576375f7f
# - https://dash.plot.ly/getting-started
# - https://www.phillipsj.net/posts/deploying-dash-to-google-app-engine
# - https://technovechno.com/creating-graphs-in-python-using-matplotlib-flask-framework-pythonanywhere/
# - https://rstudio-pubs-static.s3.amazonaws.com/375295_bc1b2d98c9604a60b56d41b36eeb5780.html#kendall-correlation
# - https://github.com/ucg8j/awesome-dash
#
# ### A/B test
#
# ### free photo
# - https://www.pexels.com/
# - https://unsplash.com/
# - https://pixabay.com/
#
# ### T test example
# - http://hamelg.blogspot.com/2015/11/python-for-data-analysis-part-24.html
#
# ### machine learning
# - https://blog.usejournal.com/stock-market-prediction-by-recurrent-neural-network-on-lstm-model-56de700bff68
#
# ### decision tree
# - https://silburt.github.io/blog/fundamental_analysis.html
#
# ### video analysis
# - https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_video/py_table_of_contents_video/py_table_of_contents_video.html
#
#
# ### image analysis
# - https://medium.com/tensorflow/an-introduction-to-biomedical-image-analysis-with-tensorflow-and-dltk-2c25304e7c13
#
# ### latex
# - https://www.codecogs.com/latex/eqneditor.php
#
# ### hypothesis testing
# - https://www.datacamp.com/community/tutorials/stocks-significance-testing-p-hacking
# - https://machinelearningmastery.com/time-series-data-stationary-python/
# - https://www.quantconnect.com/tutorials/introduction-to-financial-python/confidence-interval-and-hypothesis-testing
# - http://www.insightsbot.com/blog/1MH61d/augmented-dickey-fuller-test-in-python
# - https://books.google.com/books?id=E93SBQAAQBAJ&pg=PA322&lpg=PA322&dq=python+Financial+Data+p+value&source=bl&ots=VroT8GljTw&sig=ACfU3U2uA-eBgP5-IuSBRQlwjTjWaZmzBQ&hl=en&sa=X&ved=2ahUKEwj19p6mybDgAhWrmOAKHR0YALUQ6AEwCXoECAIQAQ#v=onepage&q=python%20Financial%20Data%20p%20value&f=false
# - https://s3.amazonaws.com/assets.datacamp.com/production/course_5612/slides/chapter1.pdf
# - https://plot.ly/python/normality-test/
# - https://medium.com/@pdquant/stocks-significance-testing-p-hacking-how-volatile-is-volatile-1a0da3064b8a
#
# ### prediction error
# - https://scikit-learn.org/stable/modules/model_evaluation.html
#
# ### NLP
# - https://www.kaggle.com/aaron7sun/stocknews/kernels
# - https://github.com/M-Younus/stock-market-prediction-using-sentiment-analysis
# - https://github.com/Tony607/SentimentStock/blob/master/src/SentimentStock.ipynb
# - https://github.com/ssatia/strtsmrt
# - https://github.com/niharikabalachandra/Stock-Market-Prediction-Using-Natural-Language-Processing
# - http://blog.baoduge.com/Collection_Sentiment_Analysis_Tools/
# - https://www.backtrader.com/docu/quickstart/quickstart.html
# - https://sraf.nd.edu/textual-analysis/resources/#LM%20Sentiment%20Word%20Lists
# - https://github.com/jasonyip184/StockSentimentTrading
# -

# %% [markdown]
# - https://towardsdatascience.com/efficient-frontier-portfolio-optimisation-in-python-e7844051e7f
# - https://www.analyticsvidhya.com/blog/2018/10/predicting-stock-price-machine-learningnd-deep-learning-techniques-python/
# - https://www.analyticsvidhya.com/blog/2018/08/auto-arima-time-series-modeling-python-r/
# - https://github.com/tgsmith61591/pmdarima/blob/master/examples/quick_start_example.ipynb
# - https://medium.com/ml-everything/predicting-the-stock-market-p-hacking-and-why-you-should-be-bullish-90fddc583838
# - https://www.quora.com/What-is-the-meaning-of-root-mean-squared-error-RMSE-in-statistics
# - https://github.com/fung1091/data609/blob/master/project/data609project.pdf
# - http://blog.baoduge.com/Collection_Sentiment_Analysis_Tools/
# - https://ntguardian.wordpress.com/2016/09/26/introduction-stock-market-data-python-2/
# - https://towardsdatascience.com/stock-prediction-in-python-b66555171a2
#
#
#
#
# - https://pythonprogramming.net/sp500-company-price-data-python-programming-for-finance/
# - http://rpubs.com/fung10_91/DATA607finalproject
# - file:///home/jim/Downloads/data621final.pdf
# - https://jupyter.brynmawr.edu/services/public/dblank/Jupyter%20Notebook%20Users%20Manual.ipynb
# - https://github.com/search?p=1&q=data698&type=Repositories
# - https://towardsdatascience.com/efficient-frontier-portfolio-optimisation-in-python-e7844051e7f
#
# - https://www.pythonforfinance.net/2017/01/21/investment-portfolio-optimisation-with-python/
# - http://francescopochetti.com/stock-market-prediction-part-introduction/
# - https://towardsdatascience.com/trend-seasonality-moving-average-auto-regressive-model-my-journey-to-time-series-data-with-edc4c0c8284b
# - https://medium.com/sfu-big-data/predicting-stable-portfolios-using-machine-learning-f2e27d6dbbec
#
#
# Moving average
# - https://www.kaggle.com/andreicosma/introduction-in-time-series-moving-average
#
#
#
# Topic: Porfolio optimization and Machine learning with visualization analysis for S&P 500
#
# Author: Tze Fung Lung, Jim
#
# 10 Keyword: S&P500 Stocks Return Risk Strategic Linear k-Nearest Moving-Average ARIMA LSTM
#
#
# Abstracts
#
# Predicting how the stock market will perform is one of the most difficult things to do. There are so many factors involved in the prediction – physical factors vs. physhological, rational and irrational behaviour, etc. All these aspects combine to make share prices volatile and very difficult to predict with a high degree of accuracy.
#
# The S&P 500 is widely regarded as the best single gauge of large-cap U.S. equities. The index includes 500 leading companies and captures approximately 80% coverage of available market capitalization.
#
# 1. Description of the Problem
#
# We’ll look at the S&P 500, an index of the largest US companies. The S&P 500 is an American stock market index based on the market capitalizations of 500 large companies having common stock listed on the NYSE, NASDAQ Exchange. I will load all 500 dataset in S&P 500 for analysis by using porfolio optimization to get the possible several stocks with higher return and lower risk. And using the machine learning predict the investment trend for S&P 500 index.
#
#     - What are the top 20 higher monthly return among all 500 number of stocks in S&P500 by Mathematical programming? The target is to find out the top valuable, higher return with lower risk of stocks.
#
#     - Could I invest these top 20 stocks now by analysis for the trend of S&P500 index by Machine learning? It is to determine if I could invest these stocks by choosing the most accuracy model with the trend.
#
# 2. Why the problem is interesting
#
# Automatic trading without anyone involved will be the trend of stock market near furture. I would like to use the data science methods to make a strategic for investment.
#
# I will study which method of machine learning would be more accurate, suitable for prediction by using root-mean-squared error, that the prediction will be more meaningful in use.
#
#
#
# 3. What other approaches have been tried
#
# First of all, I will contruct the porfolio optimization in order to achieve a maximum expected return given their risk preferences due to the fact that the returns of a portfolio are greatly affected by nature of the relationship between assets and their weights in the portfolio.
#
# The top 20 monthly return of stocks will be get into the portfolio optimization. Then in order to get the higher return and lower risk of stocks, the portfolio optimization will be conducted to find out which are the best choose of investment and generate the visualization for returns and volatility.
#
# For the next part, I will work with historical data about the S&P500 price index to understand if I can invest in market this moment. I will implement a mix of machine learning algorithms to predict the future stock price of this company, starting with simple algorithms like averaging and linear regression, and then moving on to advanced techniques like Auto ARIMA and LSTM. And I will compare the models by using root-mean-squared error (RMSE) to measure of how model performed and measure difference between predicted values and the actual values.
#
#
# 4. Discussion on your hypothesis is and how you specific solution will improve
#
# Stock market analysis is divided into two parts – Fundamental Analysis and Technical Analysis.
#
# Fundamental Analysis involves analyzing the company’s future profitability on the basis of its current business environment and financial performance.
# Technical Analysis, on the other hand, includes reading the charts and using statistical figures to identify the trends in the stock market.
#
# We’ll scrapy all S&P 500 tickers from Wiki and load all 500 dataset to be in cleaning and appending the adjusted closing price from 2008 to 2018.
#
# - Moving Average
# The predicted closing price for each day will be the average of a set of previously observed values. Instead of using the simple average, we will be using the moving average technique which uses the latest set of values for each prediction.
#
# - Linear Regression
# The most basic machine learning algorithm that can be implemented on this data is linear regression. The linear regression model returns an equation that determines the relationship between the independent variables and the dependent variable.
#
# - k-Nearest Neighbors
# Another interesting ML algorithm that one can use here is kNN (k nearest neighbours). Based on the independent variables, kNN finds the similarity between new data points and old data points.
#
# - ARIMA
# ARIMA is a very popular statistical method for time series forecasting. ARIMA models take into account the past values to predict the future values.
#
# - Long Short Term Memory (LSTM)
# LSTMs are widely used for sequence prediction problems and have proven to be extremely effective.
#
# 5. Issues
#
# 6. Effects of Edgeworth Cycles
#
# 7. Additional Features
